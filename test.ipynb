# %%
from fft_utils import FFTProcessor

fft_processor = FFTProcessor()

# %%
nll1 = fft_processor.load_nll('sample/sample_nll_bbc_gemma2-2b_out.txt')
print(nll1[0][:10])
print(len(nll1[0]))
# Out:
# [8.4014, 9.0977, 8.9356, 0.161, 4.5881, 6.9429, 0.6957, 0.1079, 0.6261, 3.6406]
# 1112

# %%
nll2 = fft_processor.load_nll('sample/sample_nll_bbc_gemma2-2b_pythia-410m.txt')
print(nll2[0][:10])
print(len(nll2[0]))
# Out:
# [8.3723, 9.0805, 8.9227, 0.1601, 4.5804, 6.9739, 0.7077, 0.1109, 0.6229, 3.6525]
# 1124

# %%
import numpy as np

diffs = []
for i in range(len(nll1)):
    s1 = np.array(nll1[i])
    s2 = np.array(nll2[i])
    min_len = min(len(s1), len(s2))
    d = s1[:min_len] - s2[:min_len]
    diffs.extend(d.tolist())

diffs = np.array(diffs)
print('mean of diffs:', diffs.mean())
print('sd of diffs:', diffs.std())
# Out:
# mean of diffs: 0.13366806420319255
# sd of diffs: 3.1480590671979725

# %%
# check if the length difference of 2 is consistent
length_diffs = [len(s1) - len(s2) for s1, s2 in zip(nll1, nll2)]
print('length differences:', length_diffs)
# Out:
# length differences: [-12, -7, -7, -12, -26, -7, -18, -40, -21, -14, -10, -8, -10, -23, -21, -19, -7, -21, -26, -17, -34, -12, -11, -11, -15, -35, -11, -35, -37, -10, -13, -38, -16, -3, -9, -11, -26, -17, -42, -5, -16, -23, -25, -47, -38, -4, -27, -9, -22, -19, -5, -35, -8, -13, -16, -24, -5, -7, -38, -10, -28, -16, -10, -3, -8, -16, -27, -12, -24, -12, -9, -2, -9, -13, -9, -33, -13, -37, -26, -13, -16, -8, -30, -25, -18, -28, -18, -11, -6, -5, -26, -7, -11, -8, -21, -1, -10, -8, -26, -17, -23, -11, -33, -4, -38, -9, -19, -12, -30, -11, -10, -18, -30, -18, -8, -25, -10, -12, -13, -12, -23, -10, -5, -10, -23, -31, -26, -38, -7, -19, -11, -32, -13, -9, -51, -30, -7, -20, -6, -37, -34, -4, -32, -10, -31, -12, -15, -5, -25, -29]

# %%
from face_score import FACEScorer

# %%
face_scorer = FACEScorer(model_path='gpt2', device='cpu')

nlls = face_scorer.texts_to_nll(texts=['hello, this is a sentence.', 'this is another sentence'])
# Out:
# /Users/xy/.pyenv/versions/miniconda3-latest/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
#   0%|          | 0/1 [00:00<?, ?it/s]/Users/xy/.pyenv/versions/miniconda3-latest/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:2855: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(
# 100%|██████████| 1/1 [00:00<00:00, 15.04it/s]

# %%
print(nlls)
# Out:
# [tensor([2.0405, 6.8283, 1.0895, 1.8515, 8.4510, 2.9173]), tensor([3.6254, 6.1920, 7.7326])]

# %%
input_file = 'data/wsj_raw_utf8.txt'

input_data = []
with open(input_file, 'r') as f:
    for line in f:
        input_data.append(line.strip())

print(len(input_data))
# Out:
# 3613

# %%
from tqdm import tqdm

nlls = face_scorer.texts_to_nll(texts=input_data)
# Out:
#   0%|          | 0/904 [00:00<?, ?it/s]/Users/xy/.pyenv/versions/miniconda3-latest/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:2855: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(
# 100%|██████████| 904/904 [01:20<00:00, 11.21it/s]

# %%
face_scorer.save_nll(nlls, 'data/wsj_nlls.txt')
